# %% [markdown]
# ## Process
# This should multi channel process data

# %%
import configuration.configuration as cfg
import numpy as np
import matplotlib.pyplot as plt
from measurement.measurement import state_vector
from measurement.arclength import slow
import argparse
from measurement.measurement import state_vector
import os
# %matplotlib notebook

# %%
#%% Load the radar configuration
radar = cfg.loadConfiguration("/home/ishuwa_tinda/local/src/Python/radarAugust2019/radar/radar/XML/sureConfig2M1.xml")
#radar = cfg.loadConfiguration("E:\\Python\\myrdr2\\radar\\XML\\sureTest1M.xml")
# Out:
# Computing satellite positions for channel 6
# [6, 7, 8]
# [Done]
# Computing satellite positions for channel 3
# [3, 4, 5]
# [Done]
# Computing satellite positions for channel 0
# [0, 1, 2]
# [Done]

# %%
pth = "/home/ishuwa_tinda/local/src/Python/radarAugust2019/radar/radar" 
#pth = "E:\\Python\\myrdr2\\radar" 
fls = [os.path.join(pth, r['filename']) for r in radar]
print(fls)
# Out:
# ['/home/ishuwa_tinda/local/src/Python/radarAugust2019/radar/radar/sureConfig_c0b0.npy', '/home/ishuwa_tinda/local/src/Python/radarAugust2019/radar/radar/sureConfig_c1b0.npy', '/home/ishuwa_tinda/local/src/Python/radarAugust2019/radar/radar/sureConfig_c2b0.npy', '/home/ishuwa_tinda/local/src/Python/radarAugust2019/radar/radar/sureConfig_c0b1.npy', '/home/ishuwa_tinda/local/src/Python/radarAugust2019/radar/radar/sureConfig_c1b1.npy', '/home/ishuwa_tinda/local/src/Python/radarAugust2019/radar/radar/sureConfig_c2b1.npy', '/home/ishuwa_tinda/local/src/Python/radarAugust2019/radar/radar/sureConfig_c0b2.npy', '/home/ishuwa_tinda/local/src/Python/radarAugust2019/radar/radar/sureConfig_c1b2.npy', '/home/ishuwa_tinda/local/src/Python/radarAugust2019/radar/radar/sureConfig_c2b2.npy']

# %%
data = np.stack([np.fft.fft(np.load(fl), axis=1) for fl in fls], axis=0)

# %%
#%% Define which bands to look at
bands = np.arange(-6,7)

# %%
#%% Define the arrays
rad = radar[int(len(radar)/2)]
f0 = rad['antenna']['fc']
ref = rad['acquisition']
fs = 1.0/ref['rangeSampleSpacing']
Nr = ref['numRangeSamples']
Na = ref['numAzimuthSamples']
prf = ref['prf']

cSat = int(Na/2)
sv = state_vector()
xState = sv.expandedState(ref['satellitePositions'][1][cSat], 0.0)
print(xState)
satXYZ = xState[0,:]
print(satXYZ)
satvXvYvZ = xState[1,:]
C = slow(ref['satellitePositions'][0])
cdf, tdf, T, N, B, kappa, tau, dkappa = C.diffG(xState)
vs = np.linalg.norm(satvXvYvZ)
print("Vsat: %0.4f" % vs)

ksp = prf/vs
ksp = 1.0/(C.ds(1.0/prf))
kr = 4.0*np.pi*cfg.FFT_freq(Nr, fs, 0.0)/cfg.physical.c + 4.0*np.pi*f0/cfg.physical.c

ks = np.array([2.0*np.pi*cfg.FFT_freq(Na, ksp, b*ksp) for b in bands])
ksidx = np.argsort(ks.flatten())
# Out:
# [[-5.28682312e+05 -6.12367494e+06  3.49575006e+06]
#  [ 1.41881893e+03 -3.79246085e+03 -6.42886115e+03]
#  [ 3.99533796e-02  6.66246450e+00 -3.95049973e+00]
#  [-6.16326859e-04  4.28944342e-03  7.24134857e-03]]
# [ -528682.31212671 -6123674.94137327  3495750.06305126]
# kappa: 1.341802995e-07 tau: 1.641681929e-08 dkappa: -1.218258580e-17
# Vsat: 7597.7669

# %%
#Calculate spatial offsets from motion
s_offsets = [C.ds((r['acquisition']['satellitePositions'][0][0] 
              - radar[0]['acquisition']['satellitePositions'][0][0]).total_seconds()) for r in radar]
#s_offsets = np.array([0.0,0.0,0.0,1.0,1.0,1.0,2.0,2.0,2.0])
print(s_offsets)
# Out:
# [0.0, 0.0, 0.0, 3.039106769432474, 3.039106769432474, 3.039106769432474, 6.078213542797968, 6.078213542797968, 6.078213542797968]

# %%
#%% Generate the antenna patterns for all channels
H = np.array([cfg.twoWayArrayPatternLinearKS(ks, rd, kr[0], ds) for rd,ds in zip(radar,s_offsets)])

# %%
print(H.shape)
print(data.shape)
# Out:
# (9, 13, 5316)
# (9, 8192, 5316)

# %%
#%% Generate the desired "final" antenna pattern
D = np.sqrt(np.sum(np.abs(H)**2, axis=0))

# %%
# %matplotlib notebook
plt.figure()
plt.plot(D.flatten()[ksidx])
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
intf01 = np.sum(data[0,:,:], axis=0)*np.conj(np.sum(data[4,:,:], axis=0))
print(intf01.shape)
plt.plot(np.abs(intf01))
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# (5316,)

# %%
plt.figure()
hintf01 = np.sum(H[3,:,:], axis=0)*np.conj(np.sum(H[4,:,:], axis=0))
print(hintf01.shape)
plt.plot(np.angle(hintf01))
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# (5316,)

# %%
#%% Use a noise matrix
Rn = np.eye(len(radar))

# %%
#%% Set the blend factor
p = 0.5

# %%
myH = np.sum(H[:,:,:],axis=1)
nrm = np.max(np.abs(myH.flatten()))
print(nrm)
myH = myH/nrm
myH.shape
# Out:
# 71889.29045655832
# (9, 5316)

# %%
plt.figure()
plt.plot(ks[2,:],np.abs(myH[0,:]),'.')
plt.grid()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
ix0 = 0
ix1 = 0
plt.figure()
hintf01 = H[ix0,:,:].flatten()*np.conj(H[ix1,:,:].flatten())
print(hintf01.shape)
plt.plot(ks.flatten(), np.abs(hintf01.flatten()),'.')
plt.grid()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# (69108,)

# %%
ix0 = 0
ix1 = 1
plt.figure()
hintf01 = H[ix0,:,:].flatten()*np.conj(H[ix1,:,:].flatten())
print(hintf01.shape)
plt.plot(ks.flatten(), np.unwrap(np.angle(hintf01)),'.')
plt.grid()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# (69108,)

# %%
kidx=0
p=1.0
Hmin = H[:,:,kidx]
#print(Hmin)
#print(np.linalg.eig(Hmin))
#Rinv = np.linalg.inv(Hmin)
#Rinv = np.linalg.inv(np.dot(Hmin, np.conj(Hmin.T)) + (1.0-p)/p*Rn[0:3,0:3])
#print(np.angle(Rinv))
plt.figure()
plt.imshow(np.abs(Hmin))
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
myD = np.sum(data,axis=1)
myD = myD/np.max(np.abs(myD))

# %%
myH = np.sum(H,axis=1)
nrm = np.max(np.abs(myH.flatten()))
myH = myH/nrm

# %%
ix0 = 3
ix1 = 4
myintD = myD[ix0,:]*np.conj(myD[ix1,:])
myintH = myH[ix0,:]*np.conj(myH[ix1,:])
print(myintD.shape)
print(myintH.shape)
plt.figure()
plt.plot(ks[2,:],np.angle(myintD),'.', ks[2,:],np.angle(myintH),'.')
plt.show()
# Out:
# (5316,)
# (5316,)
# <img src="data:image/png;base64,..." width="640">

# %%
ix0 = 8
ix1 = 0
myintD = myD[ix0,:]*np.conj(myD[ix1,:])
myintH = myH[ix0,:]*np.conj(myH[ix1,:])
plt.figure()
plt.plot(ks[2,:],np.abs(myintD),'.', ks[2,:],np.abs(myintH),'.')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
kidx=0
p=1.0e-7
Hmin = H[:,:,kidx]
print(Hmin.shape)
#print(np.linalg.eig(Hmin))
#Rinv = np.linalg.inv(Hmin)
Rinv = np.linalg.inv(np.dot(Hmin, np.conj(Hmin.T)) + (1.0-p)/p*Rn)
B = np.dot(np.conj(Hmin.T), Rinv)
print(B.shape)
dummy = np.dot(B,myD[:,kidx])
#B = np.dot(np.diag(D[:,kidx]), np.dot(np.conj(H[:,:,kidx].T), Rinv))
print(np.dot(np.conj(H[:,:,kidx].T), Rinv).shape)
#print(np.diag(D[:,kidx]).shape)
#print(data[:,:,kidx].shape)
#dummy = np.dot(B,data[:,:,kidx])
#print(dummy.shape)
plt.figure()
plt.imshow(np.angle(B))
plt.show()
# Out:
# (9, 13)
# (13, 9)
# (13, 9)
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
plt.plot(bands,np.abs(dummy), bands,np.abs(dummy),'o')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#%% Compute the inverse matrices
Nb = len(bands)
procData = np.zeros((Nb,Na,Nr), dtype=np.complex128)
for kidx in range(Na):
    if kidx%300 == 1:
        print("Progess: %0.2f" % (100.0*kidx/Na))
    Rinv = np.linalg.inv(np.dot(H[:,:,kidx], np.conj(H[:,:,kidx].T)) + (1.0-p)/p*Rn)
    B = np.dot(np.diag(D[:,kidx]), np.dot(np.conj(H[:,:,kidx].T), Rinv))
    if np.any(np.isnan(B)):
        print(kidx)
        break
    dummy = np.dot(B,data[:,:,kidx])
    for bidx in range(Nb):
        procData[bidx,kidx,:] = dummy[bidx,:]
# Out:
# Progess: 0.02
# Progess: 5.66
# Progess: 11.31
# Progess: 16.95
# Progess: 22.59
# Progess: 28.24
# Progess: 33.88
# Progess: 39.52
# Progess: 45.17
# Progess: 50.81
# Progess: 56.45
# Progess: 62.10
# Progess: 67.74
# Progess: 73.38
# Progess: 79.03
# Progess: 84.67
# Progess: 90.31
# Progess: 95.96

# %%
#%% Reorder the data
procData = procData.reshape((Nb*Na, Nr))
procData = procData[ksidx,:]

# %%
#%% Re-order for inverse transform
ks_full = 2.0*np.pi*cfg.FFT_freq(Na*Nb, ksp*Nb, 0)
print(procData.shape)
print(ks_full.shape)
ks_full_idx = np.argsort(ks_full) - (2 - len(ks_full)%2)
procData = procData[ks_full_idx,:]
# Out:
# (69108, 8192)
# (69108,)

# %%
#%% Look at a plot
plt.figure()
plt.plot(np.abs(np.sum(procData,axis=1)),'.')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#%%
procData = np.fft.ifft(procData, axis=0)

# %%
#%%
flatProc = np.sum(procData, axis=1)

# %%
#%%
plt.figure()
plt.plot(np.abs(flatProc))
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#%%
cAntenna = int(len(radar)/2)
refTimePos = radar[cAntenna]['acquisition']['satellitePositions']
rfIDX = int(len(refTimePos[0])/2)

pointXYZ, satSV = cfg.computeReferenceGroundPoint(radar, 
                                                  radarIDX = cAntenna, 
                                                  rTargetIndex = 400, 
                                                  sTargetIndex = rfIDX)

# %%
C.t2s()

# %%
#%%
s = np.arange(Na*Nb)/(ksp*Nb)
#s = np.arange(Na)/ksp
#slow_t = np.arange(Na)/prf
#slow_t -= np.mean(slow_t)
s = s - np.mean(s) + 3.0
#s.shape
#s = C.s + 10.5
print(cdf)
rngs_curve = np.outer(cdf[0] - pointXYZ, s**0) + np.outer(cdf[1],s) + np.outer(cdf[2], (s**2)/2.0) + np.outer(cdf[3], (s**3)/6.0)
rngs = np.sqrt(np.sum(rngs_curve*rngs_curve, axis=0))
#rngs = sat_curve - np.repmat(pointXYZ, (1,Na*Nb))
rC = np.exp(-1j*kr[0]*rngs)
# Out:
# [array([ -528682.31212671, -6123674.94137327,  3495750.06305126]), array([ 0.18674157, -0.49915467, -0.8461514 ]), array([ 6.12599874e-10,  1.15627747e-07, -6.80749708e-08]), array([-1.19817592e-15,  9.17664657e-15,  1.56000894e-14])]

# %%
s.shape
# Out:
# (69108,)

# %%
#%%
plt.figure()
plt.plot(np.unwrap(np.angle(flatProc*np.conj(rC))),'.')
plt.grid()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
tData = procData.reshape((Nb*Na, Nr))
tData = tData[ksidx,:]

# %%
ks_full = 2.0*np.pi*cfg.FFT_freq(Na*Nb, ksp*Nb, 0)
ks_full_idx = np.argsort(ks_full)
tData = tData[ks_full_idx,:]
print(tData.shape)
print(ks_full.shape)
#plt.figure()
#plt.plot((np.arange(Na*Nb))[ks_full_idx])
#plt.show()

# %%
tData = np.fft.ifft(tData,axis=0)

# %%
np.max(np.abs(procData))
tSlice = np.sum(tData, axis=1)

# %%
cAntenna = int(len(radar)/2)
refTimePos = radar[cAntenna]['acquisition']['satellitePositions']
rfIDX = int(len(refTimePos[0])/2)

pointXYZ, satSV = cfg.computeReferenceGroundPoint(radar, 
                                                  radarIDX = cAntenna, 
                                                  rTargetIndex = 400, 
                                                  sTargetIndex = rfIDX)

# %%
plt.figure()
plt.plot(np.unwrap(np.angle(tSlice)))
plt.grid()
plt.show()

# %%
s = np.arange(Na*Nb)/(ksp*Nb)
s = s - np.mean(s)
s.shape
print(cdf)
rngs_curve = np.outer(cdf[0] - pointXYZ, s**0) + np.outer(cdf[1],s) + np.outer(cdf[2], (s**2)/2.0) + np.outer(cdf[3], (s**3)/6.0)
rngs = np.sqrt(np.sum(rngs_curve*rngs_curve, axis=0))
#rngs = sat_curve - np.repmat(pointXYZ, (1,Na*Nb))
rC = np.exp(-1j*kr[0]*rngs)
plt.figure()
plt.plot(np.unwrap(np.angle(tSlice*np.conj(rC))),'.')
plt.grid()
plt.show()

# %%
ntData = np.fft.ifft(tData, axis=1)

# %%
plt.figure()
plt.plot(np.abs(tData.flatten()[ksidx]))
plt.show()

# %%
nprocData = procData.reshape((m*n, Nr))[ksidx, :]
nprocData.shape

# %%
plt.figure()
plt.plot(np.unwrap(np.angle(np.sum(nprocData,axis=1))))
plt.show()

# %%
np.dot(B,data[:,:,0]).shape

# %%
procData.shape

# %%
procData[:,:,0] = np.dot(B[:,:,0],data[:,:,0])
