# %% [markdown]
# # Ernesto's first notebook

# %% [markdown]
# This also has latex $\int_0^{\infty}f(x)$

# %%
import numpy as ish
from scipy.constants import c
import matplotlib.pyplot as plt

# %%
print(c)
# Out:
# 299792458.0

# %%
x = ishange(0,100,0.1)
y = np.sin(x/2/np.pi)

# %%
plt.figure()
plt.plot(x,y, '.')
plt.grid()
plt.xlabel("$\sum$")
plt.title("First plot")
plt.show()
